# %% [markdown]
# # Python Tutorial to Retrieve AQS HAPS data through API
#
# author: Theresa Lincheck
#
# date: 02-17-2026

# %% [markdown]
# Import Libraries
# - `requests` requests.get function is used to retrieve contents from a given url
# - `json` is used to interpret json files
# - `pandas` is used to convert json to tabular format

# %%
import requests
import json
import pandas as pd
TODO: # Add text above about urllib
from urllib.request import urlretrieve, urlopen

# bdate - begin date of data selection in YYYYMMDD format
# edate - end date of data selection in YYYYMMDD format; END DATE MUST BE IN THE SAME YEAR AS THE BEGIN DATE

# https://aqs.epa.gov/data/api/metaData/fieldsByService?email=test@aqs.api&key=test&service=list

# %% [markdown]
# To access the EPA's data from the Air Quality System (AQS), we will first create a url with the correct parameters. We'll do this by creating a function that builds urls for us.
# For each url, you will need a username (email address) and key to access the api data.
# If not already setup, visit https://www.google.com/url?q=https%3A%2F%2Faqs.epa.gov%2Faqsweb%2Fdocuments%2Fdata_api.html to create an account and get a user key.
#
# You can alternatively use test credentials for small data queries:
# user = "test@aqs.api"
# key = "test"

# %%
# Define user and key credentials; replace with your specific credentials
email = "theresa.lincheck@deq.ok.gov"
key = "orangemouse22"

# %%
# Define functions to create url for API data retrieval

# By state, county, and site
def make_url_bySite(param, bdate, edate, state, county, site):
    base = f"https://aqs.epa.gov/data/api/sampleData/bySite?email={email}&key={key}"
    url = f"{base}&param={param}&bdate={bdate}&edate={edate}&state={state}&county={county}&site={site}"
    return url

# By state
def make_url_byState(param, bdate, edate, state):
    base = f"https://aqs.epa.gov/data/api/sampleData/byState?email={email}&key={key}"
    url2 = f"{base}&param={param}&bdate={bdate}&edate={edate}&state={state}"
    return url2

# %%
# Define inputs for your function
param = 43502 # Formaldehyde # paramter code(s)
bdate = 20240101 # beginning date
edate = 20241231 # end date
state = 40 # state code; OK = 40
county = 109 # county(s) of interest
site = 1037 # site(s) of interest

# Generate urls
site_url = make_url_bySite(param, bdate, edate, state, county, site) # plug values in
print(site_url) # see url

state_url = make_url_byState(param, bdate, edate, state) # plug values in
print(state_url) # see url2
# Out:
# https://aqs.epa.gov/data/api/sampleData/bySite?email=theresa.lincheck@deq.ok.gov&key=orangemouse22&param=43502&bdate=20240101&edate=20241231&state=40&county=109&site=1037
# https://aqs.epa.gov/data/api/sampleData/byState?email=theresa.lincheck@deq.ok.gov&key=orangemouse22&param=43502&bdate=20240101&edate=20241231&state=40

# %%
# use requests.get function to retreive contents (i.e. data) from a given url
r = requests.get(state_url, verify=False)
# Out:
# c:\Users\378306\.conda\envs\toxics\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aqs.epa.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
# use json.loads function to tell the code that the content we want is in json format
contents = json.loads(r.text)

# see the contents of the web page
contents
# Out:
# {'Header': [{'status': 'Success',
#    'request_time': '2026-02-18T15:29:45-05:00',
#    'url': 'https://aqs.epa.gov/data/api/sampleData/byState?email=theresa.lincheck@deq.ok.gov&key=orangemouse22&param=43502&bdate=20240101&edate=20241231&state=40',
#    'rows': 203}],
#  'Data': [{'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-01-25',
#    'time_local': '00:00',
#    'date_gmt': '2024-01-25',
#    'time_gmt': '06:00',
#    'sample_measurement': None,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.1,
#    'uncertainty': None,
#    'qualifier': 'TS - Holding Time Or Transport Temperature Is Out Of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-05-24',
#    'time_local': '00:00',
#    'date_gmt': '2024-05-24',
#    'time_gmt': '06:00',
#    'sample_measurement': None,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.1,
#    'uncertainty': None,
#    'qualifier': 'AQ - Collection Error.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-10-03',
#    'time_local': '00:00',
#    'date_gmt': '2024-10-03',
#    'time_gmt': '06:00',
#    'sample_measurement': None,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.1,
#    'uncertainty': None,
#    'qualifier': 'AK - Filter Leak.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2025-03-27',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-11-08',
#    'time_local': '00:00',
#    'date_gmt': '2024-11-08',
#    'time_gmt': '06:00',
#    'sample_measurement': None,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.1,
#    'uncertainty': None,
#    'qualifier': 'AN - Machine Malfunction.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2025-03-27',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-11-14',
#    'time_local': '00:00',
#    'date_gmt': '2024-11-14',
#    'time_gmt': '06:00',
#    'sample_measurement': None,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.1,
#    'uncertainty': None,
#    'qualifier': 'AN - Machine Malfunction.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2025-03-27',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-01-31',
#    'time_local': '00:00',
#    'date_gmt': '2024-01-31',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.8,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-03-01',
#    'time_local': '00:00',
#    'date_gmt': '2024-03-01',
#    'time_gmt': '06:00',
#    'sample_measurement': 1.7,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-03-07',
#    'time_local': '00:00',
#    'date_gmt': '2024-03-07',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.3,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-03-13',
#    'time_local': '00:00',
#    'date_gmt': '2024-03-13',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.2,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-03-19',
#    'time_local': '00:00',
#    'date_gmt': '2024-03-19',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.3,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-03-25',
#    'time_local': '00:00',
#    'date_gmt': '2024-03-25',
#    'time_gmt': '06:00',
#    'sample_measurement': 1.4,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-04-30',
#    'time_local': '00:00',
#    'date_gmt': '2024-04-30',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.9,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-05-30',
#    'time_local': '00:00',
#    'date_gmt': '2024-05-30',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.8,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-06-05',
#    'time_local': '00:00',
#    'date_gmt': '2024-06-05',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.6,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-06-11',
#    'time_local': '00:00',
#    'date_gmt': '2024-06-11',
#    'time_gmt': '06:00',
#    'sample_measurement': 4.2,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-06-17',
#    'time_local': '00:00',
#    'date_gmt': '2024-06-17',
#    'time_gmt': '06:00',
#    'sample_measurement': 3.6,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-06-29',
#    'time_local': '00:00',
#    'date_gmt': '2024-06-29',
#    'time_gmt': '06:00',
#    'sample_measurement': 4.5,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-07-05',
#    'time_local': '00:00',
#    'date_gmt': '2024-07-05',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.8,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-07-11',
#    'time_local': '00:00',
#    'date_gmt': '2024-07-11',
#    'time_gmt': '06:00',
#    'sample_measurement': 5.4,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-07-17',
#    'time_local': '00:00',
#    'date_gmt': '2024-07-17',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.9,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-07-23',
#    'time_local': '00:00',
#    'date_gmt': '2024-07-23',
#    'time_gmt': '06:00',
#    'sample_measurement': 4.2,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-07-29',
#    'time_local': '00:00',
#    'date_gmt': '2024-07-29',
#    'time_gmt': '06:00',
#    'sample_measurement': 3.1,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': 'DN - DNPH peak less than NATTS TAD requirement, reported value should be considered an estimate.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-08-04',
#    'time_local': '00:00',
#    'date_gmt': '2024-08-04',
#    'time_gmt': '06:00',
#    'sample_measurement': 6.7,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-08-10',
#    'time_local': '00:00',
#    'date_gmt': '2024-08-10',
#    'time_gmt': '06:00',
#    'sample_measurement': 3.2,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-08-16',
#    'time_local': '00:00',
#    'date_gmt': '2024-08-16',
#    'time_gmt': '06:00',
#    'sample_measurement': 5.2,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-08-22',
#    'time_local': '00:00',
#    'date_gmt': '2024-08-22',
#    'time_gmt': '06:00',
#    'sample_measurement': 5.5,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': 'DN - DNPH peak less than NATTS TAD requirement, reported value should be considered an estimate.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-09-05',
#    'time_local': '00:00',
#    'date_gmt': '2024-09-05',
#    'time_gmt': '06:00',
#    'sample_measurement': 4.8,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03922,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2025-01-09',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-09-27',
#    'time_local': '00:00',
#    'date_gmt': '2024-09-27',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.7,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03792,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2025-01-09',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '109',
#    'site_number': '1037',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 35.614131,
#    'longitude': -97.475083,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-10-27',
#    'time_local': '00:00',
#    'date_gmt': '2024-10-27',
#    'time_gmt': '06:00',
#    'sample_measurement': 3.7,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.038,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Oklahoma',
#    'date_of_last_change': '2025-03-27',
#    'cbsa_code': '36420'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-03-19',
#    'time_local': '00:00',
#    'date_gmt': '2024-03-19',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.9,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03971,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-03-25',
#    'time_local': '00:00',
#    'date_gmt': '2024-03-25',
#    'time_gmt': '06:00',
#    'sample_measurement': 1.1,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03971,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-03-31',
#    'time_local': '00:00',
#    'date_gmt': '2024-03-31',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.1,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03971,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-04-06',
#    'time_local': '00:00',
#    'date_gmt': '2024-04-06',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.8,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03971,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-04-12',
#    'time_local': '00:00',
#    'date_gmt': '2024-04-12',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.8,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03971,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-05-18',
#    'time_local': '00:00',
#    'date_gmt': '2024-05-18',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.7,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03971,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-09-21',
#    'time_local': '00:00',
#    'date_gmt': '2024-09-21',
#    'time_gmt': '06:00',
#    'sample_measurement': 4.6,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03971,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2025-01-09',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-01-01',
#    'time_local': '00:00',
#    'date_gmt': '2024-01-01',
#    'time_gmt': '06:00',
#    'sample_measurement': 0.7,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-01-07',
#    'time_local': '00:00',
#    'date_gmt': '2024-01-07',
#    'time_gmt': '06:00',
#    'sample_measurement': 0.9,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': 'HT - Sample pick-up hold time exceeded.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-01-13',
#    'time_local': '00:00',
#    'date_gmt': '2024-01-13',
#    'time_gmt': '06:00',
#    'sample_measurement': 0.6,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-01-19',
#    'time_local': '00:00',
#    'date_gmt': '2024-01-19',
#    'time_gmt': '06:00',
#    'sample_measurement': 0.4,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-01-25',
#    'time_local': '00:00',
#    'date_gmt': '2024-01-25',
#    'time_gmt': '06:00',
#    'sample_measurement': 0.6,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-01-31',
#    'time_local': '00:00',
#    'date_gmt': '2024-01-31',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.7,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-02-06',
#    'time_local': '00:00',
#    'date_gmt': '2024-02-06',
#    'time_gmt': '06:00',
#    'sample_measurement': 1.7,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-02-12',
#    'time_local': '00:00',
#    'date_gmt': '2024-02-12',
#    'time_gmt': '06:00',
#    'sample_measurement': 0.7,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-02-18',
#    'time_local': '00:00',
#    'date_gmt': '2024-02-18',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.0,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-02-24',
#    'time_local': '00:00',
#    'date_gmt': '2024-02-24',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.7,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-03-01',
#    'time_local': '00:00',
#    'date_gmt': '2024-03-01',
#    'time_gmt': '06:00',
#    'sample_measurement': 1.7,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-03-07',
#    'time_local': '00:00',
#    'date_gmt': '2024-03-07',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.4,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-03-13',
#    'time_local': '00:00',
#    'date_gmt': '2024-03-13',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.1,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-04-18',
#    'time_local': '00:00',
#    'date_gmt': '2024-04-18',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.2,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-04-24',
#    'time_local': '00:00',
#    'date_gmt': '2024-04-24',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.4,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-04-30',
#    'time_local': '00:00',
#    'date_gmt': '2024-04-30',
#    'time_gmt': '06:00',
#    'sample_measurement': 3.0,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-05-06',
#    'time_local': '00:00',
#    'date_gmt': '2024-05-06',
#    'time_gmt': '06:00',
#    'sample_measurement': 1.5,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03963,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '1127',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.204902,
#    'longitude': -95.976537,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-11-02',
#    'time_local': '00:00',
#    'date_gmt': '2024-11-02',
#    'time_gmt': '06:00',
# ...
#    'date_gmt': '2024-06-23',
#    'time_gmt': '06:00',
#    'sample_measurement': None,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.1,
#    'uncertainty': None,
#    'qualifier': 'BN - Sample Value Exceeds Media Limit.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-07-23',
#    'time_local': '00:00',
#    'date_gmt': '2024-07-23',
#    'time_gmt': '06:00',
#    'sample_measurement': None,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.1,
#    'uncertainty': None,
#    'qualifier': 'BN - Sample Value Exceeds Media Limit.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-07-29',
#    'time_local': '00:00',
#    'date_gmt': '2024-07-29',
#    'time_gmt': '06:00',
#    'sample_measurement': None,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.1,
#    'uncertainty': None,
#    'qualifier': 'BN - Sample Value Exceeds Media Limit.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-08-04',
#    'time_local': '00:00',
#    'date_gmt': '2024-08-04',
#    'time_gmt': '06:00',
#    'sample_measurement': None,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.1,
#    'uncertainty': None,
#    'qualifier': 'BN - Sample Value Exceeds Media Limit.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-08-16',
#    'time_local': '00:00',
#    'date_gmt': '2024-08-16',
#    'time_gmt': '06:00',
#    'sample_measurement': None,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.1,
#    'uncertainty': None,
#    'qualifier': 'BN - Sample Value Exceeds Media Limit.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-08-22',
#    'time_local': '00:00',
#    'date_gmt': '2024-08-22',
#    'time_gmt': '06:00',
#    'sample_measurement': None,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.1,
#    'uncertainty': None,
#    'qualifier': 'BN - Sample Value Exceeds Media Limit.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-08-28',
#    'time_local': '00:00',
#    'date_gmt': '2024-08-28',
#    'time_gmt': '06:00',
#    'sample_measurement': None,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.1,
#    'uncertainty': None,
#    'qualifier': 'AE - Shelter Temperature Outside Limits.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-02-18',
#    'time_local': '00:00',
#    'date_gmt': '2024-02-18',
#    'time_gmt': '06:00',
#    'sample_measurement': 2.4,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.03971,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-06-28',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-05-30',
#    'time_local': '00:00',
#    'date_gmt': '2024-05-30',
#    'time_gmt': '06:00',
#    'sample_measurement': 18.1,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.20018,
#    'uncertainty': None,
#    'qualifier': 'DI - Sample was diluted for analysis.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-06-05',
#    'time_local': '00:00',
#    'date_gmt': '2024-06-05',
#    'time_gmt': '06:00',
#    'sample_measurement': 15.1,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.20018,
#    'uncertainty': None,
#    'qualifier': 'DI - Sample was diluted for analysis.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-06-11',
#    'time_local': '00:00',
#    'date_gmt': '2024-06-11',
#    'time_gmt': '06:00',
#    'sample_measurement': 17.4,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.20018,
#    'uncertainty': None,
#    'qualifier': 'DI - Sample was diluted for analysis.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-06-17',
#    'time_local': '00:00',
#    'date_gmt': '2024-06-17',
#    'time_gmt': '06:00',
#    'sample_measurement': 16.9,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.20018,
#    'uncertainty': None,
#    'qualifier': 'DI - Sample was diluted for analysis.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-06-29',
#    'time_local': '00:00',
#    'date_gmt': '2024-06-29',
#    'time_gmt': '06:00',
#    'sample_measurement': 16.5,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.20018,
#    'uncertainty': None,
#    'qualifier': 'DI - Sample was diluted for analysis.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-10-17',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-07-05',
#    'time_local': '00:00',
#    'date_gmt': '2024-07-05',
#    'time_gmt': '06:00',
#    'sample_measurement': 14.5,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.20018,
#    'uncertainty': None,
#    'qualifier': 'DI - Sample was diluted for analysis.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-07-11',
#    'time_local': '00:00',
#    'date_gmt': '2024-07-11',
#    'time_gmt': '06:00',
#    'sample_measurement': 18.3,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.20018,
#    'uncertainty': None,
#    'qualifier': 'DI - Sample was diluted for analysis.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-07-17',
#    'time_local': '00:00',
#    'date_gmt': '2024-07-17',
#    'time_gmt': '06:00',
#    'sample_measurement': 15.2,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.20018,
#    'uncertainty': None,
#    'qualifier': 'DI - Sample was diluted for analysis.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-08-10',
#    'time_local': '00:00',
#    'date_gmt': '2024-08-10',
#    'time_gmt': '06:00',
#    'sample_measurement': 12.3,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.20018,
#    'uncertainty': None,
#    'qualifier': 'DI - Sample was diluted for analysis.',
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2024-12-09',
#    'cbsa_code': '46140'},
#   {'state_code': '40',
#    'county_code': '143',
#    'site_number': '0235',
#    'parameter_code': '43502',
#    'poc': 6,
#    'latitude': 36.126945,
#    'longitude': -95.998941,
#    'datum': 'WGS84',
#    'parameter': 'Formaldehyde',
#    'date_local': '2024-11-02',
#    'time_local': '00:00',
#    'date_gmt': '2024-11-02',
#    'time_gmt': '06:00',
#    'sample_measurement': 9.0,
#    'units_of_measure': 'Parts per billion Carbon',
#    'units_of_measure_code': '078',
#    'sample_duration': '24 HOUR',
#    'sample_duration_code': '7',
#    'sample_frequency': 'EVERY 6TH DAY',
#    'detection_limit': 0.04012,
#    'uncertainty': None,
#    'qualifier': None,
#    'method_type': 'Non-FRM',
#    'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#    'method_code': '202',
#    'state': 'Oklahoma',
#    'county': 'Tulsa',
#    'date_of_last_change': '2025-03-27',
#    'cbsa_code': '46140'}]}

# %%
# index by key to only get the contents in "Data" section
data = contents["Data"]
data
# Out:
# [{'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-01-25',
#   'time_local': '00:00',
#   'date_gmt': '2024-01-25',
#   'time_gmt': '06:00',
#   'sample_measurement': None,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.1,
#   'uncertainty': None,
#   'qualifier': 'TS - Holding Time Or Transport Temperature Is Out Of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-05-24',
#   'time_local': '00:00',
#   'date_gmt': '2024-05-24',
#   'time_gmt': '06:00',
#   'sample_measurement': None,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.1,
#   'uncertainty': None,
#   'qualifier': 'AQ - Collection Error.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-10-03',
#   'time_local': '00:00',
#   'date_gmt': '2024-10-03',
#   'time_gmt': '06:00',
#   'sample_measurement': None,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.1,
#   'uncertainty': None,
#   'qualifier': 'AK - Filter Leak.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2025-03-27',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-11-08',
#   'time_local': '00:00',
#   'date_gmt': '2024-11-08',
#   'time_gmt': '06:00',
#   'sample_measurement': None,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.1,
#   'uncertainty': None,
#   'qualifier': 'AN - Machine Malfunction.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2025-03-27',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-11-14',
#   'time_local': '00:00',
#   'date_gmt': '2024-11-14',
#   'time_gmt': '06:00',
#   'sample_measurement': None,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.1,
#   'uncertainty': None,
#   'qualifier': 'AN - Machine Malfunction.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2025-03-27',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-01-31',
#   'time_local': '00:00',
#   'date_gmt': '2024-01-31',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.8,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-03-01',
#   'time_local': '00:00',
#   'date_gmt': '2024-03-01',
#   'time_gmt': '06:00',
#   'sample_measurement': 1.7,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-03-07',
#   'time_local': '00:00',
#   'date_gmt': '2024-03-07',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.3,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-03-13',
#   'time_local': '00:00',
#   'date_gmt': '2024-03-13',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.2,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-03-19',
#   'time_local': '00:00',
#   'date_gmt': '2024-03-19',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.3,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-03-25',
#   'time_local': '00:00',
#   'date_gmt': '2024-03-25',
#   'time_gmt': '06:00',
#   'sample_measurement': 1.4,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-04-30',
#   'time_local': '00:00',
#   'date_gmt': '2024-04-30',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.9,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-05-30',
#   'time_local': '00:00',
#   'date_gmt': '2024-05-30',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.8,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-06-05',
#   'time_local': '00:00',
#   'date_gmt': '2024-06-05',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.6,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-06-11',
#   'time_local': '00:00',
#   'date_gmt': '2024-06-11',
#   'time_gmt': '06:00',
#   'sample_measurement': 4.2,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-06-17',
#   'time_local': '00:00',
#   'date_gmt': '2024-06-17',
#   'time_gmt': '06:00',
#   'sample_measurement': 3.6,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-06-29',
#   'time_local': '00:00',
#   'date_gmt': '2024-06-29',
#   'time_gmt': '06:00',
#   'sample_measurement': 4.5,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-07-05',
#   'time_local': '00:00',
#   'date_gmt': '2024-07-05',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.8,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-07-11',
#   'time_local': '00:00',
#   'date_gmt': '2024-07-11',
#   'time_gmt': '06:00',
#   'sample_measurement': 5.4,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-07-17',
#   'time_local': '00:00',
#   'date_gmt': '2024-07-17',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.9,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-07-23',
#   'time_local': '00:00',
#   'date_gmt': '2024-07-23',
#   'time_gmt': '06:00',
#   'sample_measurement': 4.2,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-07-29',
#   'time_local': '00:00',
#   'date_gmt': '2024-07-29',
#   'time_gmt': '06:00',
#   'sample_measurement': 3.1,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': 'DN - DNPH peak less than NATTS TAD requirement, reported value should be considered an estimate.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-08-04',
#   'time_local': '00:00',
#   'date_gmt': '2024-08-04',
#   'time_gmt': '06:00',
#   'sample_measurement': 6.7,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-08-10',
#   'time_local': '00:00',
#   'date_gmt': '2024-08-10',
#   'time_gmt': '06:00',
#   'sample_measurement': 3.2,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-08-16',
#   'time_local': '00:00',
#   'date_gmt': '2024-08-16',
#   'time_gmt': '06:00',
#   'sample_measurement': 5.2,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-08-22',
#   'time_local': '00:00',
#   'date_gmt': '2024-08-22',
#   'time_gmt': '06:00',
#   'sample_measurement': 5.5,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': 'DN - DNPH peak less than NATTS TAD requirement, reported value should be considered an estimate.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-09-05',
#   'time_local': '00:00',
#   'date_gmt': '2024-09-05',
#   'time_gmt': '06:00',
#   'sample_measurement': 4.8,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03922,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2025-01-09',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-09-27',
#   'time_local': '00:00',
#   'date_gmt': '2024-09-27',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.7,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03792,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2025-01-09',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '109',
#   'site_number': '1037',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 35.614131,
#   'longitude': -97.475083,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-10-27',
#   'time_local': '00:00',
#   'date_gmt': '2024-10-27',
#   'time_gmt': '06:00',
#   'sample_measurement': 3.7,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.038,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Oklahoma',
#   'date_of_last_change': '2025-03-27',
#   'cbsa_code': '36420'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-03-19',
#   'time_local': '00:00',
#   'date_gmt': '2024-03-19',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.9,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03971,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-03-25',
#   'time_local': '00:00',
#   'date_gmt': '2024-03-25',
#   'time_gmt': '06:00',
#   'sample_measurement': 1.1,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03971,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-03-31',
#   'time_local': '00:00',
#   'date_gmt': '2024-03-31',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.1,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03971,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-04-06',
#   'time_local': '00:00',
#   'date_gmt': '2024-04-06',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.8,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03971,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-04-12',
#   'time_local': '00:00',
#   'date_gmt': '2024-04-12',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.8,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03971,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-05-18',
#   'time_local': '00:00',
#   'date_gmt': '2024-05-18',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.7,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03971,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-09-21',
#   'time_local': '00:00',
#   'date_gmt': '2024-09-21',
#   'time_gmt': '06:00',
#   'sample_measurement': 4.6,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03971,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2025-01-09',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-01-01',
#   'time_local': '00:00',
#   'date_gmt': '2024-01-01',
#   'time_gmt': '06:00',
#   'sample_measurement': 0.7,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-01-07',
#   'time_local': '00:00',
#   'date_gmt': '2024-01-07',
#   'time_gmt': '06:00',
#   'sample_measurement': 0.9,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': 'HT - Sample pick-up hold time exceeded.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-01-13',
#   'time_local': '00:00',
#   'date_gmt': '2024-01-13',
#   'time_gmt': '06:00',
#   'sample_measurement': 0.6,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-01-19',
#   'time_local': '00:00',
#   'date_gmt': '2024-01-19',
#   'time_gmt': '06:00',
#   'sample_measurement': 0.4,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-01-25',
#   'time_local': '00:00',
#   'date_gmt': '2024-01-25',
#   'time_gmt': '06:00',
#   'sample_measurement': 0.6,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-01-31',
#   'time_local': '00:00',
#   'date_gmt': '2024-01-31',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.7,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-02-06',
#   'time_local': '00:00',
#   'date_gmt': '2024-02-06',
#   'time_gmt': '06:00',
#   'sample_measurement': 1.7,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-02-12',
#   'time_local': '00:00',
#   'date_gmt': '2024-02-12',
#   'time_gmt': '06:00',
#   'sample_measurement': 0.7,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-02-18',
#   'time_local': '00:00',
#   'date_gmt': '2024-02-18',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.0,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-02-24',
#   'time_local': '00:00',
#   'date_gmt': '2024-02-24',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.7,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-03-01',
#   'time_local': '00:00',
#   'date_gmt': '2024-03-01',
#   'time_gmt': '06:00',
#   'sample_measurement': 1.7,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-03-07',
#   'time_local': '00:00',
#   'date_gmt': '2024-03-07',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.4,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-03-13',
#   'time_local': '00:00',
#   'date_gmt': '2024-03-13',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.1,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-04-18',
#   'time_local': '00:00',
#   'date_gmt': '2024-04-18',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.2,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-04-24',
#   'time_local': '00:00',
#   'date_gmt': '2024-04-24',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.4,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-04-30',
#   'time_local': '00:00',
#   'date_gmt': '2024-04-30',
#   'time_gmt': '06:00',
#   'sample_measurement': 3.0,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': 'TT - Transport Temperaure is Out of Specs.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-05-06',
#   'time_local': '00:00',
#   'date_gmt': '2024-05-06',
#   'time_gmt': '06:00',
#   'sample_measurement': 1.5,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-11-02',
#   'time_local': '00:00',
#   'date_gmt': '2024-11-02',
#   'time_gmt': '06:00',
#   'sample_measurement': 1.5,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03963,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2025-03-27',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-06-05',
#   'time_local': '00:00',
#   'date_gmt': '2024-06-05',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.0,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03955,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '1127',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.204902,
#   'longitude': -95.976537,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-06-13',
#   'time_local': '00:00',
#   'date_gmt': '2024-06-13',
#   'time_gmt': '06:00',
#   'sample_measurement': 5.2,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
# ...
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Ottawa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '33060'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-06-23',
#   'time_local': '00:00',
#   'date_gmt': '2024-06-23',
#   'time_gmt': '06:00',
#   'sample_measurement': None,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.1,
#   'uncertainty': None,
#   'qualifier': 'BN - Sample Value Exceeds Media Limit.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-07-23',
#   'time_local': '00:00',
#   'date_gmt': '2024-07-23',
#   'time_gmt': '06:00',
#   'sample_measurement': None,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.1,
#   'uncertainty': None,
#   'qualifier': 'BN - Sample Value Exceeds Media Limit.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-07-29',
#   'time_local': '00:00',
#   'date_gmt': '2024-07-29',
#   'time_gmt': '06:00',
#   'sample_measurement': None,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.1,
#   'uncertainty': None,
#   'qualifier': 'BN - Sample Value Exceeds Media Limit.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-08-04',
#   'time_local': '00:00',
#   'date_gmt': '2024-08-04',
#   'time_gmt': '06:00',
#   'sample_measurement': None,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.1,
#   'uncertainty': None,
#   'qualifier': 'BN - Sample Value Exceeds Media Limit.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-08-16',
#   'time_local': '00:00',
#   'date_gmt': '2024-08-16',
#   'time_gmt': '06:00',
#   'sample_measurement': None,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.1,
#   'uncertainty': None,
#   'qualifier': 'BN - Sample Value Exceeds Media Limit.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-08-22',
#   'time_local': '00:00',
#   'date_gmt': '2024-08-22',
#   'time_gmt': '06:00',
#   'sample_measurement': None,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.1,
#   'uncertainty': None,
#   'qualifier': 'BN - Sample Value Exceeds Media Limit.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-08-28',
#   'time_local': '00:00',
#   'date_gmt': '2024-08-28',
#   'time_gmt': '06:00',
#   'sample_measurement': None,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.1,
#   'uncertainty': None,
#   'qualifier': 'AE - Shelter Temperature Outside Limits.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-02-18',
#   'time_local': '00:00',
#   'date_gmt': '2024-02-18',
#   'time_gmt': '06:00',
#   'sample_measurement': 2.4,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.03971,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-06-28',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-05-30',
#   'time_local': '00:00',
#   'date_gmt': '2024-05-30',
#   'time_gmt': '06:00',
#   'sample_measurement': 18.1,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.20018,
#   'uncertainty': None,
#   'qualifier': 'DI - Sample was diluted for analysis.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-06-05',
#   'time_local': '00:00',
#   'date_gmt': '2024-06-05',
#   'time_gmt': '06:00',
#   'sample_measurement': 15.1,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.20018,
#   'uncertainty': None,
#   'qualifier': 'DI - Sample was diluted for analysis.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-06-11',
#   'time_local': '00:00',
#   'date_gmt': '2024-06-11',
#   'time_gmt': '06:00',
#   'sample_measurement': 17.4,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.20018,
#   'uncertainty': None,
#   'qualifier': 'DI - Sample was diluted for analysis.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-06-17',
#   'time_local': '00:00',
#   'date_gmt': '2024-06-17',
#   'time_gmt': '06:00',
#   'sample_measurement': 16.9,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.20018,
#   'uncertainty': None,
#   'qualifier': 'DI - Sample was diluted for analysis.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-06-29',
#   'time_local': '00:00',
#   'date_gmt': '2024-06-29',
#   'time_gmt': '06:00',
#   'sample_measurement': 16.5,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.20018,
#   'uncertainty': None,
#   'qualifier': 'DI - Sample was diluted for analysis.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-10-17',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-07-05',
#   'time_local': '00:00',
#   'date_gmt': '2024-07-05',
#   'time_gmt': '06:00',
#   'sample_measurement': 14.5,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.20018,
#   'uncertainty': None,
#   'qualifier': 'DI - Sample was diluted for analysis.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-07-11',
#   'time_local': '00:00',
#   'date_gmt': '2024-07-11',
#   'time_gmt': '06:00',
#   'sample_measurement': 18.3,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.20018,
#   'uncertainty': None,
#   'qualifier': 'DI - Sample was diluted for analysis.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-07-17',
#   'time_local': '00:00',
#   'date_gmt': '2024-07-17',
#   'time_gmt': '06:00',
#   'sample_measurement': 15.2,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.20018,
#   'uncertainty': None,
#   'qualifier': 'DI - Sample was diluted for analysis.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-08-10',
#   'time_local': '00:00',
#   'date_gmt': '2024-08-10',
#   'time_gmt': '06:00',
#   'sample_measurement': 12.3,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.20018,
#   'uncertainty': None,
#   'qualifier': 'DI - Sample was diluted for analysis.',
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2024-12-09',
#   'cbsa_code': '46140'},
#  {'state_code': '40',
#   'county_code': '143',
#   'site_number': '0235',
#   'parameter_code': '43502',
#   'poc': 6,
#   'latitude': 36.126945,
#   'longitude': -95.998941,
#   'datum': 'WGS84',
#   'parameter': 'Formaldehyde',
#   'date_local': '2024-11-02',
#   'time_local': '00:00',
#   'date_gmt': '2024-11-02',
#   'time_gmt': '06:00',
#   'sample_measurement': 9.0,
#   'units_of_measure': 'Parts per billion Carbon',
#   'units_of_measure_code': '078',
#   'sample_duration': '24 HOUR',
#   'sample_duration_code': '7',
#   'sample_frequency': 'EVERY 6TH DAY',
#   'detection_limit': 0.04012,
#   'uncertainty': None,
#   'qualifier': None,
#   'method_type': 'Non-FRM',
#   'method': 'SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLET ABSORPTION',
#   'method_code': '202',
#   'state': 'Oklahoma',
#   'county': 'Tulsa',
#   'date_of_last_change': '2025-03-27',
#   'cbsa_code': '46140'}]

# %%
data_df = pd.DataFrame(data)   # put data into DataFrame
data_df
# Out:
#     state_code county_code site_number parameter_code  poc   latitude  \
# 0           40         109        1037          43502    6  35.614131
# 1           40         109        1037          43502    6  35.614131
# 2           40         109        1037          43502    6  35.614131
# 3           40         109        1037          43502    6  35.614131
# 4           40         109        1037          43502    6  35.614131
# ..         ...         ...         ...            ...  ...        ...
# 198         40         143        0235          43502    6  36.126945
# 199         40         143        0235          43502    6  36.126945
# 200         40         143        0235          43502    6  36.126945
# 201         40         143        0235          43502    6  36.126945
# 202         40         143        0235          43502    6  36.126945
#
#      longitude  datum     parameter  date_local  ... detection_limit  \
# 0   -97.475083  WGS84  Formaldehyde  2024-01-25  ...         0.10000
# 1   -97.475083  WGS84  Formaldehyde  2024-05-24  ...         0.10000
# 2   -97.475083  WGS84  Formaldehyde  2024-10-03  ...         0.10000
# 3   -97.475083  WGS84  Formaldehyde  2024-11-08  ...         0.10000
# 4   -97.475083  WGS84  Formaldehyde  2024-11-14  ...         0.10000
# ..         ...    ...           ...         ...  ...             ...
# 198 -95.998941  WGS84  Formaldehyde  2024-07-05  ...         0.20018
# 199 -95.998941  WGS84  Formaldehyde  2024-07-11  ...         0.20018
# 200 -95.998941  WGS84  Formaldehyde  2024-07-17  ...         0.20018
# 201 -95.998941  WGS84  Formaldehyde  2024-08-10  ...         0.20018
# 202 -95.998941  WGS84  Formaldehyde  2024-11-02  ...         0.04012
#
#     uncertainty                                          qualifier  \
# 0          None  TS - Holding Time Or Transport Temperature Is ...
# 1          None                             AQ - Collection Error.
# 2          None                                  AK - Filter Leak.
# 3          None                          AN - Machine Malfunction.
# 4          None                          AN - Machine Malfunction.
# ..          ...                                                ...
# 198        None              DI - Sample was diluted for analysis.
# 199        None              DI - Sample was diluted for analysis.
# 200        None              DI - Sample was diluted for analysis.
# 201        None              DI - Sample was diluted for analysis.
# 202        None                                               None
#
#      method_type                                             method  \
# 0        Non-FRM  SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLE...
# 1        Non-FRM  SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLE...
# 2        Non-FRM  SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLE...
# 3        Non-FRM  SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLE...
# 4        Non-FRM  SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLE...
# ..           ...                                                ...
# 198      Non-FRM  SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLE...
# 199      Non-FRM  SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLE...
# 200      Non-FRM  SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLE...
# 201      Non-FRM  SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLE...
# 202      Non-FRM  SILICA-DNPH-CART-KI O3 SCRUB - HPLC ULTRAVIOLE...
#
#     method_code     state    county date_of_last_change  cbsa_code
# 0           202  Oklahoma  Oklahoma          2024-06-28      36420
# 1           202  Oklahoma  Oklahoma          2024-10-17      36420
# 2           202  Oklahoma  Oklahoma          2025-03-27      36420
# 3           202  Oklahoma  Oklahoma          2025-03-27      36420
# 4           202  Oklahoma  Oklahoma          2025-03-27      36420
# ..          ...       ...       ...                 ...        ...
# 198         202  Oklahoma     Tulsa          2024-12-09      46140
# 199         202  Oklahoma     Tulsa          2024-12-09      46140
# 200         202  Oklahoma     Tulsa          2024-12-09      46140
# 201         202  Oklahoma     Tulsa          2024-12-09      46140
# 202         202  Oklahoma     Tulsa          2025-03-27      46140
#
# [203 rows x 29 columns]

# %%
data_df['sample_duration'].unique()
# Out:
# array(['24 HOUR'], dtype=object)
